# %% [markdown]
# # Programming Assignment
# # Data Pre-processing, Exploratory Analysis and Data Prediction using Machine Learning

# %% [markdown]
# ## Description
#
# There are two parts in this assignment:
# - #### Part A
#   - You will have an opportunity to apply data pre-processing techniques that you learned in the class to a problem. In addition, you will do exploratory analysis on the given dataset.
#
# - #### Part B
#   - You will have an opportunity to apply machine learning techniques that you learned in the class to a problem. In addition, you will learn to perform machine learning with the Keras Python library.
#
# To get started on this assignment, you need to download the given dataset and read the description carefully written on this page. Please note that all implementation of your program should be done with Python.
# <br/><br/>

# %% [markdown]
# ### Intended Learning Outcomes
#
# - Upon completion of <strong>Part A</strong> of this assignment, you should be able to:
# <ol>
#     <li>Demonstrate your understanding on how to pre-process data using the algorithms / techniques as described in the class.</li>
#     <li>Use simple descriptive statistical approaches to understand your data.</li>
#     <li>Construct Python program to analyse the data and draw simple conclusions from it.</li>
# </ol>
# <br />
#
# - Upon completion of <strong>Part 2</strong> of this assignment, you should be able to:
# <ol>
#     <li>Demonstrate your understanding on how to do prediction using the machine learning algorithms / techniques as described in the class.</li>
#     <li>Construct Python program to learn from the training data and do data prediction for the testing set.</li>
# </ol>

# %% [markdown]
# ### Required Libraries
# The following libraries are required for this assignment:
# <ol>
#     <li>Numpy - Numerical python</li>
#     <li>Scipy - Scientific python</li>
#     <li>Matplotlib - Python 2D plotting library</li>
#     <li>Seaborn - Visualization library based on matplotlib</li>
#     <li>Pandas - Python data analysis library</li>
#     <li>Keras - Deep learning library</li>
# </ol>

# %% [markdown]
# ### Dataset ~ Titanic (titanic-train.csv)
# This dataset contains the following features:
# <ul>
#     <li>PassengerId</li>
#     <li>Survived (Survival: 0 = No; 1 = Yes)</li>
#     <li>Pclass (Passenger Class: 1 = 1st; 2 = 2nd; 3 = 3rd)</li>
#     <li>Name (Name of the passenger)</li>
#     <li>Sex (Sex of the passenger)</li>
#     <li>Age (Age of the passenger)</li>
#     <li>SibSp (Number of siblings / spourses aboard)</li>
#     <li>Parch (Number of parents / children aboard)</li>
#     <li>Ticket (Ticket number of the passenger)</li>
#     <li>Fare (Passenger fare)</li>
#     <li>Cabin (Cabin number of the passenger)</li>
#     <li>Embarked (Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton) )</li>
# </ul>

# %% [markdown]
# ## Steps:
# <ol>
#     <li>Part A: Data Pre-processing and Exploratory Analysis
#       (i.e. Preparing the training data)
#       <ul>
#       <li>1 Importing data and exploring the features.</li>
#       <li>2 Cleaning data: Handling missing values</li>
#       <li>3 Creating new features and dropping redundant features.</li>
#       <li>4 Transforming data.</li>
#       <li>5 Analysing data statistically.</li>
#       </ul>
#     </li>
#     <li>Part B: Data Prediction using Machine Learning
#       <ul>
#       <li>1. Training the model. (Assignment 2)</li>
#       <li>2. Preparing the testing data (Assignment 2)</li>
#           <ul>
#           <li>1 Importing data and exploring the features.</li>
#           <li>2 Cleaning data: Handling missing values</li>
#           <li>3 Creating new features and dropping redundant features.</li>
#           <li>4 Transforming data.</li>
#           </ul>
#       <li>3. Doing data prediction using the trained model.</li>
#       </ul>
#     </li>
# </ol>

# %% [markdown]
# ## Part A: Data Pre-processing and Exploratory Analysis

# %% [markdown]
# ### Step 1: Importing data and exploring the features
#
# #### Step 1.1
# To start working with the Titanic dataset, you will need to import the required libraries, and read the data into a pandas DataFrame.
# - Import the following libraries using import statements.
# <ul>
#     <li>pandas (for data manipulation)</li>
#     <li>numpy (for multidimensional array computation)</li>
#     <li>seaborn and matplotlib.pyplot (both for data visualization)</li>
# </ul>
# - Read the csv file 'titanic-train.csv' using Pandas' read_csv function
# (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html">pandas.read_csv</a>)
#
# Note: Run a code cell by clicking on the cell and using the keyboard shortcut &lt;Shift&gt; + &lt;Enter&gt;.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('titanic-train.csv')

# %% [markdown]
# #### Step 1.2
# Use head function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.head.html">pandas.DataFrame.head</a>) of pandas library to preview the first 10 data.

# %%
print(df.head(10))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %% [markdown]
# #### Step 1.3
# Use tail function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.tail.html">pandas.DataFrame.tail</a>) of pandas library to preview the last 10 data.

# %%
print(df.tail(10))
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 881    male  33.0      0      0            349257   7.8958   NaN        S
# 882  female  22.0      0      0              7552  10.5167   NaN        S
# 883    male  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884    male  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 885  female  39.0      0      5            382652  29.1250   NaN        Q
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q

# %% [markdown]
# #### Step 1.4
# Display informtion on dataframe using info function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.info.html">pandas.DataFrame.info</a>) of pandas library.

# %%
# Display information about the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# #### Step 1.5
# Evaluate the data quality & perform missing values assessment using isnull function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.isnull.html">pandas.isnull</a>) and sum function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sum.html">pandas.DataFrame.sum</a>) of pandas library.

# %%
missing_values = df.isnull().sum()

print(missing_values[missing_values > 0])
# Out:
# Age         177
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# <span style="color:red">What is your observation?</span>

# %% [markdown]
# Age:
# There are 177 missing values in the Age column. This is a significant number, as it represents a substantial portion of the dataset. Handling these missing values is crucial for accurate analysis and modeling.
# Cabin:
# The Cabin column has 687 missing values, which is extremely high (approximately 77% of the data). Given the large number of missing entries, it may be more effective to drop this column entirely or to analyze it further if there's a method to impute or derive useful information.
# Embarked:
# There are only 2 missing values in the Embarked column. This is a very small fraction of the dataset, and these can easily be filled with the mode or dropped without significantly affecting the analysis.

# %% [markdown]
# #### Step 1.6
# Evaluate the distribution of categorical features (e.g., Name, Sex, Ticket, Cabin, and Embarked) using describe function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.describe.html">pandas.DataFrame.describe</a>) of the pandas library.

# %%
categorical_summary = df.describe(include='object')

print(categorical_summary)
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %% [markdown]
# <span style="color:red">What is your observation?</span>

# %% [markdown]
# Name:
# Count: There are 891 entries, indicating the dataset is complete for this field.
# Unique: There are 891 unique names, which means each passenger has a distinct name.
# Top: The most common name is "Braund, Mr. Owen Harris", appearing only once.
# Sex:
# Count: All 891 entries are present.
# Unique: There are 2 unique values: male and female.
# Top: The most common value is "male", which appears 577 times (about 65% of the dataset). This indicates a significant gender imbalance in the dataset.
# Ticket:
# Count: All 891 entries are accounted for.
# Unique: There are 681 unique ticket numbers, suggesting many passengers had different tickets, with some shared.
# Top: The most frequent ticket number is "347082", appearing 7 times.
# Cabin:
# Count: Only 204 entries are non-null, indicating a significant amount of missing data (687 entries are missing).
# Unique: There are 147 unique cabin entries, suggesting many passengers did not have assigned cabins.
# Top: The most common cabin entry is "B96 B98", which appears 4 times.
# Embarked:
# Count: There are 889 entries, with 2 missing values.
# Unique: There are 3 unique embarkation points.
# Top: The most common embarkation point is "S" (Southampton), appearing 644 times, indicating it was the primary port of embarkation for passengers.

# %% [markdown]
# ### Step 2: Cleaning data: Handling missing values

# %% [markdown]
# #### Step 2.1
# Refer to Step 1.5, there are missing values in three features.
# For the feature with the second least number of missing values, evaluate its distribution using hist function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.hist.html">pandas.DataFrame.hist</a>) of pandas library.

# %%
df['Age'].hist(bins=30, color='skyblue', edgecolor='black')

plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.grid(False)  # Optional: to remove the grid for a cleaner look
plt.show()

# %% [markdown]
# <span style="color:red">What is your observation?</span>

# %% [markdown]
# A bell shape histogram with count heavily centered at age around 20-30. The count for age of infant is a bit high which make the histogram a skewed bell shape.

# %% [markdown]
# #### Step 2.2
# For the feature with the least missing values, evaluate the distribution using countplot function (<a href="https://seaborn.pydata.org/generated/seaborn.countplot.html">seaborn.countplot</a>) of seaborn library.

# %%
sns.countplot(data=df, x='Embarked', palette='pastel')

plt.title('Distribution of Embarked Feature')
plt.xlabel('Embarked')
plt.ylabel('Count')
plt.show()
# Out:
# /var/folders/sg/4n9pw8hs0719q3wb9rbg6_z00000gn/T/ipykernel_4507/2421163812.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Embarked', palette='pastel')

# %% [markdown]
# <span style="color:red">What is your observation?</span>

# %% [markdown]
# Approximately 650 passengers embarked from Southampton (S), making it the most common embarkation point by a significant margin. This indicates that Southampton was likely the primary departure port for the Titanic.
# Around 200 passengers embarked from Cherbourg (C). While this number is notable, it is significantly lower than those embarking from Southampton.
# Only about 100 passengers boarded from Queenstown (Q), which is the lowest among the three ports.

# %% [markdown]
# #### Step 2.3
# - For the feature with the second least missing values, if the data is not skewed, using mean to impute the missing values. Otherwise using median.
# - For the feature with the least missing values, impute the missing values with most the common value.

# %% [markdown]
# ##### Step 2.3.1
# Compute the mean OR median of the second least missing values using mean (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.mean.html">pandas.DataFrame.mean</a>) / median function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.median.html">pandas.DataFrame.median</a>) of pandas library.
#
# Note: You have to skip all the missing values when computing the mean or median.

# %%
mean_age = df['Age'].mean()
mean_age
# Out:
# 29.69911764705882

# %% [markdown]
# <span style="color:red">What is your observation?</span>
# Write down your observation here in the cell:

# %% [markdown]
# Mean age = 29.69911764705882

# %% [markdown]
# ##### Step 2.3.2
# Use mean / median to impute the missing values of the feature with the second least missing values. fillna function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.fillna.html">pandas.DataFrame.fillna</a>) of pandas library can be used.

# %%
mean_age = df['Age'].mean()

df['Age'] = df['Age'].fillna(mean_age)

# %% [markdown]
# ##### Step 2.3.3
# Use the most common value of the feature with the least missing values to impute the missing values. Again, fillna function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.fillna.html">pandas.DataFrame.fillna</a>) of the pandas library can be used.

# %%
most_common_embarked = df['Embarked'].mode()[0]

df['Embarked'] = df['Embarked'].fillna(most_common_embarked)

# %% [markdown]
# ### Step 3: Creating new features and dropping redundant features

# %% [markdown]
# #### Step 3.1
# Create a new feature called Family based on Parch and SibSp.
# - Define a new feature 'Family' and assign it with the sum of SibSp and Parch.

# %%
df['Family'] = df['SibSp'] + df['Parch']

# %% [markdown]
# #### Step 3.2
# Use head function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.head.html">pandas.DataFrame.head</a>) of pandas library to preview the first 10 data.

# %%
df['Family'].head(10)
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    0
# 5    0
# 6    0
# 7    4
# 8    2
# 9    1
# Name: Family, dtype: int64

# %% [markdown]
# #### Step 3.3
# - PassengerId, Name, Ticket, and Cabin may be dropped (using drop function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.drop.html">pandas.DataFrame.drop</a>) of the pandas library) as they contain high ratio of duplicates and there may not be a correlation to survivial.
# - In addition, SibSp and Parch can be dropped as the feature 'Family' has been defined.

# %%
df.drop(columns=['PassengerId', 'Name', 'Ticket', 'Cabin', 'SibSp', 'Parch'], inplace=True)

# %% [markdown]
# #### Step 3.4
# Use head function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.head.html">pandas.DataFrame.head</a>) of pandas library to preview the first 10 data.

# %%
df.head(10)
# Out:
#    Survived  Pclass     Sex   Age     Fare Embarked  Family
# 0         0       3    male  22.0   7.2500        S       1
# 1         1       1  female  38.0  71.2833        C       1
# 2         1       3  female  26.0   7.9250        S       0
# 3         1       1  female  35.0  53.1000        S       1
# 4         0       3    male  35.0   8.0500        S       0
# 5         0       3    male   NaN   8.4583        Q       0
# 6         0       1    male  54.0  51.8625        S       0
# 7         0       3    male   2.0  21.0750        S       4
# 8         1       3  female  27.0  11.1333        S       2
# 9         1       2  female  14.0  30.0708        C       1

# %% [markdown]
# ### Step 4: Transforming data

# %% [markdown]
# ##### Step 4.1
# - Update the Family's values using where function (<a href="https://docs.scipy.org/doc/numpy-1.14.0/reference/generated/numpy.where.html">numpy.where</a>) of numpy library as follows:
# <ul>
#     <li>0 if the Family's count is 0, which means single.</li>
#     <li>1 if the Family's count is greater than or equal to 1 AND less than or equal to 4, which means small family.</li>
#     <li>2 if the Family's count is greater than or equal to 5, means large family</li>
# </ul>

# %%
df['Family'] = np.where(df['Family'] == 0, 0, 
                np.where((df['Family'] >= 1) & (df['Family'] <= 4), 1, 2))

# %% [markdown]
# #### Step 4.2
# - Update the Sex's values to 1 if the original value is 'male'. Otherwise, update it to 0.
# - where function (<a href="https://docs.scipy.org/doc/numpy-1.14.0/reference/generated/numpy.where.html">numpy.where</a>) of numpy library can be used.

# %%
df['Sex'] = np.where(df['Sex'] == 'male', 1, 0)

# %% [markdown]
# #### Step 4.3
# - Update the Embarked values using where function (<a href="https://docs.scipy.org/doc/numpy-1.14.0/reference/generated/numpy.where.html">numpy.where</a>) of numpy library as follows:
# <ul>
#     <li>0 if the Embarked value is C.</li>
#     <li>1 if the Embarked value is Q.</li>
#     <li>2 if teh Embarked value is S.</li>
# </ul>

# %%
df['Embarked'] = np.where(df['Embarked'] == 'C', 0,
                   np.where(df['Embarked'] == 'Q', 1,
                   np.where(df['Embarked'] == 'S', 2, np.nan)))

# %% [markdown]
# #### Step 4.4
# - Update the Fare values using where function (<a href="https://docs.scipy.org/doc/numpy-1.14.0/reference/generated/numpy.where.html">numpy.where</a>) of numpy library as follows:
# <ul>
#     <li>0 if the Fare value is less than or equal to 7.91</li>
#     <li>1 if the Fare value is greater than 7.91 AND less than or equal to 14.454</li>
#     <li>2 if the Fare value is greater than 14.454 AND less than or equal to 31</li>
#     <li>3 if the Fare value is greater than 31</li>
# </ul>

# %%
df['Fare'] = np.where(df['Fare'] <= 7.91, 0,
              np.where((df['Fare'] > 7.91) & (df['Fare'] <= 14.454), 1,
              np.where((df['Fare'] > 14.454) & (df['Fare'] <= 31), 2, 3)))

# %% [markdown]
# #### Step 4.5
# - Update the Age values using where function (<a href="https://docs.scipy.org/doc/numpy-1.14.0/reference/generated/numpy.where.html">numpy.where</a>) of numpy library as follows:
# <ul>
#     <li>0 if the Age value is less than or equal to 16</li>
#     <li>1 if the Age value is greater than 16 AND less than or equal to 32</li>
#     <li>2 if the Age value is greater than 32 AND less than or equal to 48</li>
#     <li>3 if the Age value is greater than 48 AND less than or equal to 64</li>
#     <li>4 if the Age value is greater than 64</li>
# </ul>

# %%
df['Age'] = np.where(df['Age'] <= 16, 0,
              np.where((df['Age'] > 16) & (df['Age'] <= 32), 1,
              np.where((df['Age'] > 32) & (df['Age'] <= 48), 2,
              np.where((df['Age'] > 48) & (df['Age'] <= 64), 3, 4))))

# %% [markdown]
# #### Step 4.6
# Change Embarked data to int type using astype function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.astype.html">pandas.DataFrame.astype</a>) of pandas library.

# %%
df['Embarked'] = df['Embarked'].astype(int)

# %% [markdown]
# #### Step 4.7
# Change Fare data from float to int type using astype function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.astype.html">pandas.DataFrame.astype</a>) of pandas library.

# %%
df['Fare'] = df['Fare'].astype(int)

# %% [markdown]
# #### Step 4.8
# Change Age data from float to int type using astype function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.astype.html">pandas.DataFrame.astype</a>) of pandas library.

# %%
df['Age'] = df['Age'].astype(int)

# %% [markdown]
# #### Step 4.9
# Use head function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.head.html">pandas.DataFrame.head</a>) of pandas library to preview the first 20 data.

# %%
df.head(20)
# Out:
#     Survived  Pclass  Sex  Age  Fare  Embarked  Family
# 0          0       3    1    1     0         2       1
# 1          1       1    0    2     3         0       1
# 2          1       3    0    1     1         2       0
# 3          1       1    0    2     3         2       1
# 4          0       3    1    2     1         2       0
# 5          0       3    1    4     1         1       0
# 6          0       1    1    3     3         2       0
# 7          0       3    1    0     2         2       1
# 8          1       3    0    1     1         2       1
# 9          1       2    0    0     2         0       1
# 10         1       3    0    0     2         2       1
# 11         1       1    0    3     2         2       0
# 12         0       3    1    1     1         2       0
# 13         0       3    1    2     3         2       2
# 14         0       3    0    0     0         2       0
# 15         1       2    0    3     2         2       0
# 16         0       3    1    0     2         1       2
# 17         1       2    1    4     1         2       0
# 18         0       3    0    1     2         2       1
# 19         1       3    0    4     0         0       0

# %% [markdown]
# ### Step 5: Analysing data statistically and graphically

# %% [markdown]
# #### Step 5.1
# Use describe function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.describe.html">pands.DataFrame.describe</a>) of pandas library to generate descriptive statistics that summarize the central tendency, dispersion and shape of a dataset's distribution.

# %%
statistics_summary = df.describe()
print(statistics_summary)
# Out:
#          Survived      Pclass         Sex         Age        Fare    Embarked  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642    0.647587    1.886644    1.505051    1.536476
# std      0.486592    0.836071    0.477990    1.322048    1.118148    0.791503
# min      0.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000    1.000000    0.500000    1.000000
# 50%      0.000000    3.000000    1.000000    1.000000    2.000000    2.000000
# 75%      1.000000    3.000000    1.000000    3.000000    2.000000    2.000000
# max      1.000000    3.000000    1.000000    4.000000    3.000000    2.000000
#
#            Family
# count  891.000000
# mean     0.450056
# std      0.594476
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      2.000000

# %% [markdown]
# #### Step 5.2
# Explore survival rate using countplot function (<a href="https://seaborn.pydata.org/generated/seaborn.countplot.html">seaborn.countplot</a>) of seaborn library.

# %%
sns.countplot(data=df, x='Survived', stat="percent")
plt.xlabel('Survival Status (0 = No, 1 = Yes)')
plt.ylabel('Percentage')
plt.title('Survival Rate')
plt.show()

# %% [markdown]
# #### Step 5.3
# Perform other data analysis (e.g. on the features) to explore the factors constituting higher survival rate.

# %%
sns.countplot(data=df, x="Pclass", hue="Survived", stat="percent")

plt.xlabel('Passenger Class')
plt.ylabel('Percentage')
plt.title('Survival Rate by Class')

plt.show()

# %% [markdown]
# <span style="color:red">What are your observations?</span>

# %% [markdown]
# First class passengers had the highest survival rate, while thrid class had the lowest.

# %% [markdown]
# ## Part B: Data Pre-processing and Exploratory Analysis

# %% [markdown]
# ### Step 0: Installation and Importing the libraries

# %% [markdown]
# #### Step 0.1
# We are going to use <strong>Keras</strong> which will be using <strong>Tensorflow</strong> as backend.
# Therefore, you will need to install Tensorflow and Keras first
# <br/>
# <ol>
#    <li>To install Tesnsorflow:
#       <ul>
#          <li>Start the "Anaconda Prompt" and enter the following command:<br/>
#          pip install --ignore-installed --upgrade tensorflow </li>
#          <li>For more information on installing Tensorflow: <url>https://www.tensorflow.org/install/</url></li>
#       </ul>
#    </li>
#    <li>To install Keras:
#       <ul>
#          <li>In the "Anaconda Prompt", enter the following command:<br />
#          pip install keras
#          </li>
#          <li>For more information on installing Keras: <url>https://keras.io/#installation</url></li>
#       </ul>
#    </li>
# </ol>

# %% [markdown]
# ### Step 1: Training the model
#
# #### Step 1.1
# Import the following libraries using import statements.
# <ul>
#     <li>keras (for deep learning) (Reference: <url>https://keras.io/</url>)
#         <ul>
#             <li>Sequential from keras.models</li>
#             <li>Dense from keras.layers</li>
#             <li>ModelCheckpoint from keras.callbacks</li>
#         </ul>
#     </li>
# </ul>
# Note: Run a code cell by clicking on the cell and using the keyboard shortcut &lt;Shift&gt; + &lt;Enter&gt;.
# <br />
# Note: Tensorflow and Keras have to be installed first, see <strong>Step 0.1</strong>

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint

# %% [markdown]
# #### Step 1.2
# Prepare training data - feature set and label set
# - Build feature set X by extracting 'Pclass', 'Sex', 'Age', 'Fare', 'Embarked' and 'Family' from trainData
# - Build label set Y by extracting 'Survived' from trainData

# %%
X = np.array(df[['Pclass', 'Sex', 'Age', 'Fare', 'Embarked', 'Family']])
Y = np.array(df['Survived'])

# %% [markdown]
# #### Step 1.3
# - Build a neural network to learn from the given training set - trainData.
# (Reference: <a href="https://keras.io/guides/sequential_model/">Here</a>)
# <ol>
#   <li>Initalizing a neural network using Sequential() function and name the returned object NN.</li>
#   <li>Adding the input layer and the hidden layer using add function of NN and Dense function.<br/>
#       Parameters of Dense function:
#       <ul>
#           <li>Set output_dim to 9: output_dim is the number of nodes we want to add to this layer.</li>
#           <li>kernel_initializer to 'random_uniform': the initialization of weights for stochastic gradient decent.
#           </li>
#           <li>activation to 'sigmoid': activation is the activation function of the node.</li>
#           <li>input_dim to 6: input_dim refers to the number of inputs, which is only needed for the first layer.</li>
#       </ul>
#   </li>
#   <li>Adding the output layer using add function of NN and Dense function.<br/>
#       Parameters of Dense function:
#       <ul>
#           <li>Set output_dim to 1: output_dim is the number of nodes we want to add to this layer.</li>
#           <li>kernel_initializer to 'random_uniform': the initialization of weights for stochastic gradient decent.</li>
#           <li>activation to 'sigmoid': activation is the activation function of the node.</li>
#       </ul>
#   </li>
#   <li>Prints a summary representation of our model by calling summary function of NN.</li>
# </ol>
#
# For more information about the weight initializer: <a href="here">https://keras.io/api/layers/initializers/</a>

# %%
NN = Sequential()

# Add the input layer and the hidden layer
NN.add(Dense(units=9,
             kernel_initializer='random_uniform',
             activation='sigmoid',
             input_dim=6))

# Add the output layer
NN.add(Dense(units=1,
             kernel_initializer='random_uniform',
             activation='sigmoid'))

NN.summary()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 9)              │            63 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            10 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 73 (292.00 B)
#  Trainable params: 73 (292.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### Step 1.4
# - Compile the neural network and start training
# <ol>
#   <li>Call compile function of NN to compile the neural network<br/>
#       Parameters of compile function:
#       <ul>
#           <li>loss to 'binary_crossentropy': loss is a stochastic gradient decent depends on loss. Since the dependent variable in our case is binary, we will have to use logarithmic loss function called 'binary_crossentropy'.</li>
#           <li>optimizer to 'Adam': optimizer is the algorithm that we want to use to find optimal set of weights. For details about 'Adam', please visit <a href="https://arxiv.org/abs/1412.6980v8">here</a>.
#           </li>
#           <li>metrics to ['accuracy']: metrics is the metric(s) that we want to use to improve the performance of our neural network. In our case, accuracy is the metrics.</li>
#       </ul>
#   </li>
#   <li>Call fit function of NN to train the model on training data<br/>
#       Parameters of fit function:
#       <ul>
#           <li>Set x to X: x is the numpy array of training data.</li>
#           <li>Set y to Y: y is the numpy array of label data.</li>
#           <li>Set batch_size to 32: batch_size is the number of samples per gradient update.</li>
#           <li>Set epochs to 10000: epochs is the number of epochs to train the model.</li>
#       </ul>
#   </li>
# </ol>

# %%
NN.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['accuracy'])

NN.fit(X, Y, batch_size=32, epochs=10000)
# Out:
# Epoch 1/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 658us/step - accuracy: 0.3964 - loss: 0.6987
# Epoch 2/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step - accuracy: 0.6245 - loss: 0.6835
# Epoch 3/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - accuracy: 0.6191 - loss: 0.6747
# Epoch 4/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step - accuracy: 0.6129 - loss: 0.6692
# Epoch 5/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step - accuracy: 0.6271 - loss: 0.6601
# Epoch 6/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - accuracy: 0.6293 - loss: 0.6547
# Epoch 7/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - accuracy: 0.6262 - loss: 0.6524
# Epoch 8/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step - accuracy: 0.6056 - loss: 0.6588
# Epoch 9/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step - accuracy: 0.6275 - loss: 0.6460
# Epoch 10/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step - accuracy: 0.6129 - loss: 0.6525
# Epoch 11/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - accuracy: 0.6073 - loss: 0.6521
# Epoch 12/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step - accuracy: 0.6017 - loss: 0.6524
# Epoch 13/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - accuracy: 0.6151 - loss: 0.6424
# Epoch 14/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - accuracy: 0.6244 - loss: 0.6352
# Epoch 15/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - accuracy: 0.6129 - loss: 0.6382
# Epoch 16/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - accuracy: 0.6268 - loss: 0.6268
# Epoch 17/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - accuracy: 0.6169 - loss: 0.6312
# Epoch 18/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - accuracy: 0.5876 - loss: 0.6513
# Epoch 19/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - accuracy: 0.6490 - loss: 0.6110
# Epoch 20/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - accuracy: 0.6086 - loss: 0.6314
# Epoch 21/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - accuracy: 0.6028 - loss: 0.6271
# Epoch 22/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6026 - loss: 0.6248
# Epoch 23/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - accuracy: 0.6235 - loss: 0.6070
# Epoch 24/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step - accuracy: 0.6351 - loss: 0.6000
# Epoch 25/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - accuracy: 0.6323 - loss: 0.5931
# Epoch 26/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - accuracy: 0.6129 - loss: 0.6114
# Epoch 27/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - accuracy: 0.6283 - loss: 0.5961
# Epoch 28/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - accuracy: 0.6509 - loss: 0.5794
# Epoch 29/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - accuracy: 0.6290 - loss: 0.5902
# Epoch 30/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6268 - loss: 0.5961
# Epoch 31/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - accuracy: 0.5946 - loss: 0.6125
# Epoch 32/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - accuracy: 0.6324 - loss: 0.5917
# Epoch 33/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - accuracy: 0.6495 - loss: 0.5879
# Epoch 34/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - accuracy: 0.6558 - loss: 0.5893
# Epoch 35/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - accuracy: 0.6536 - loss: 0.6042
# Epoch 36/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - accuracy: 0.6858 - loss: 0.5780
# Epoch 37/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - accuracy: 0.6779 - loss: 0.5942
# Epoch 38/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - accuracy: 0.7183 - loss: 0.5698
# Epoch 39/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step - accuracy: 0.7108 - loss: 0.5732
# Epoch 40/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step - accuracy: 0.6994 - loss: 0.5882
# Epoch 41/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - accuracy: 0.6897 - loss: 0.5889
# Epoch 42/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - accuracy: 0.7239 - loss: 0.5685
# Epoch 43/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step - accuracy: 0.6861 - loss: 0.5839
# Epoch 44/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - accuracy: 0.7239 - loss: 0.5553
# Epoch 45/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - accuracy: 0.7125 - loss: 0.5730
# Epoch 46/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step - accuracy: 0.7124 - loss: 0.5810
# Epoch 47/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - accuracy: 0.7190 - loss: 0.5903
# Epoch 48/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step - accuracy: 0.7352 - loss: 0.5589
# Epoch 49/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - accuracy: 0.7264 - loss: 0.5644
# Epoch 50/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - accuracy: 0.7351 - loss: 0.5607
# Epoch 51/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - accuracy: 0.7220 - loss: 0.5734
# Epoch 52/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - accuracy: 0.7277 - loss: 0.5745
# Epoch 53/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step - accuracy: 0.7324 - loss: 0.5618
# Epoch 54/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - accuracy: 0.7342 - loss: 0.5697
# Epoch 55/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step - accuracy: 0.7261 - loss: 0.5750
# Epoch 56/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - accuracy: 0.7396 - loss: 0.5519
# Epoch 57/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - accuracy: 0.7278 - loss: 0.5561
# Epoch 58/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - accuracy: 0.7427 - loss: 0.5521
# Epoch 59/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step - accuracy: 0.7458 - loss: 0.5554
# Epoch 60/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - accuracy: 0.7637 - loss: 0.5347
# Epoch 61/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - accuracy: 0.7435 - loss: 0.5460
# Epoch 62/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step - accuracy: 0.7464 - loss: 0.5376
# Epoch 63/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step - accuracy: 0.7281 - loss: 0.5556
# Epoch 64/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - accuracy: 0.7283 - loss: 0.5517
# Epoch 65/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - accuracy: 0.7502 - loss: 0.5437
# Epoch 66/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - accuracy: 0.7364 - loss: 0.5503
# Epoch 67/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - accuracy: 0.7203 - loss: 0.5496
# Epoch 68/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - accuracy: 0.7457 - loss: 0.5345
# Epoch 69/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step - accuracy: 0.7412 - loss: 0.5360
# Epoch 70/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step - accuracy: 0.7534 - loss: 0.5298
# Epoch 71/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - accuracy: 0.7385 - loss: 0.5463
# Epoch 72/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - accuracy: 0.7336 - loss: 0.5474
# Epoch 73/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - accuracy: 0.7365 - loss: 0.5303
# Epoch 74/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step - accuracy: 0.7527 - loss: 0.5258
# Epoch 75/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step - accuracy: 0.7626 - loss: 0.5081
# Epoch 76/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step - accuracy: 0.7431 - loss: 0.5336
# Epoch 77/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7500 - loss: 0.5305
# Epoch 78/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - accuracy: 0.7589 - loss: 0.5172
# Epoch 79/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - accuracy: 0.7401 - loss: 0.5468
# Epoch 80/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - accuracy: 0.7698 - loss: 0.5163
# Epoch 81/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 658us/step - accuracy: 0.7525 - loss: 0.5286
# Epoch 82/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - accuracy: 0.7664 - loss: 0.5085
# Epoch 83/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step - accuracy: 0.7682 - loss: 0.5160
# Epoch 84/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step - accuracy: 0.7772 - loss: 0.5198
# Epoch 85/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7459 - loss: 0.5349
# Epoch 86/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step - accuracy: 0.7919 - loss: 0.5097
# Epoch 87/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step - accuracy: 0.7771 - loss: 0.5113
# Epoch 88/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step - accuracy: 0.7753 - loss: 0.5224
# Epoch 89/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - accuracy: 0.7648 - loss: 0.5286
# Epoch 90/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step - accuracy: 0.7728 - loss: 0.5172
# Epoch 91/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step - accuracy: 0.7545 - loss: 0.5283
# Epoch 92/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - accuracy: 0.7746 - loss: 0.4974
# Epoch 93/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step - accuracy: 0.7565 - loss: 0.5210
# Epoch 94/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - accuracy: 0.7665 - loss: 0.5029
# Epoch 95/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - accuracy: 0.7704 - loss: 0.5008
# Epoch 96/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step - accuracy: 0.7775 - loss: 0.5056
# Epoch 97/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step - accuracy: 0.7778 - loss: 0.5025
# Epoch 98/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step - accuracy: 0.7798 - loss: 0.5008
# Epoch 99/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step - accuracy: 0.7626 - loss: 0.5096
# Epoch 100/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7794 - loss: 0.4858
# Epoch 101/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - accuracy: 0.7779 - loss: 0.5130
# Epoch 102/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - accuracy: 0.7827 - loss: 0.4840
# Epoch 103/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - accuracy: 0.7534 - loss: 0.5173
# Epoch 104/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step - accuracy: 0.7844 - loss: 0.4967
# Epoch 105/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - accuracy: 0.7725 - loss: 0.5047
# Epoch 106/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - accuracy: 0.7615 - loss: 0.5128
# Epoch 107/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - accuracy: 0.7774 - loss: 0.4986
# Epoch 108/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - accuracy: 0.7604 - loss: 0.5087
# Epoch 109/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - accuracy: 0.7819 - loss: 0.4871
# Epoch 110/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step - accuracy: 0.7535 - loss: 0.5136
# Epoch 111/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step - accuracy: 0.7786 - loss: 0.4776
# Epoch 112/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - accuracy: 0.7707 - loss: 0.5009
# Epoch 113/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step - accuracy: 0.7653 - loss: 0.4990
# Epoch 114/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step - accuracy: 0.7672 - loss: 0.5179
# Epoch 115/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - accuracy: 0.7814 - loss: 0.4961
# Epoch 116/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step - accuracy: 0.7671 - loss: 0.5119
# Epoch 117/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - accuracy: 0.7647 - loss: 0.4996
# Epoch 118/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step - accuracy: 0.7731 - loss: 0.4927
# Epoch 119/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - accuracy: 0.7823 - loss: 0.4901
# Epoch 120/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step - accuracy: 0.7868 - loss: 0.4831
# Epoch 121/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - accuracy: 0.7710 - loss: 0.4929
# Epoch 122/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step - accuracy: 0.7611 - loss: 0.5140
# Epoch 123/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step - accuracy: 0.7719 - loss: 0.5026
# Epoch 124/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7548 - loss: 0.5210
# Epoch 125/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step - accuracy: 0.7651 - loss: 0.4901
# Epoch 126/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step - accuracy: 0.7607 - loss: 0.5175
# Epoch 127/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step - accuracy: 0.7473 - loss: 0.5297
# Epoch 128/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - accuracy: 0.7619 - loss: 0.5144
# Epoch 129/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - accuracy: 0.7646 - loss: 0.4961
# Epoch 130/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - accuracy: 0.7691 - loss: 0.5050
# Epoch 131/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7694 - loss: 0.4934
# Epoch 132/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - accuracy: 0.7701 - loss: 0.5011
# Epoch 133/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - accuracy: 0.7673 - loss: 0.4848
# Epoch 134/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - accuracy: 0.7547 - loss: 0.5144
# Epoch 135/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.7774 - loss: 0.4855
# Epoch 136/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.7753 - loss: 0.4807
# Epoch 137/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - accuracy: 0.7708 - loss: 0.4831
# Epoch 138/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7394 - loss: 0.5223
# Epoch 139/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - accuracy: 0.7808 - loss: 0.4753
# Epoch 140/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - accuracy: 0.7655 - loss: 0.4914
# Epoch 141/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - accuracy: 0.7652 - loss: 0.5017
# Epoch 142/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - accuracy: 0.7584 - loss: 0.5115
# Epoch 143/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - accuracy: 0.7608 - loss: 0.4988
# Epoch 144/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step - accuracy: 0.7728 - loss: 0.4879
# Epoch 145/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step - accuracy: 0.7471 - loss: 0.5221
# Epoch 146/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step - accuracy: 0.7866 - loss: 0.4739
# Epoch 147/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - accuracy: 0.7784 - loss: 0.4909
# Epoch 148/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - accuracy: 0.7753 - loss: 0.4864
# Epoch 149/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step - accuracy: 0.7780 - loss: 0.4792
# Epoch 150/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - accuracy: 0.7709 - loss: 0.4822
# Epoch 151/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - accuracy: 0.7783 - loss: 0.4809
# Epoch 152/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step - accuracy: 0.7704 - loss: 0.4991
# Epoch 153/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - accuracy: 0.7652 - loss: 0.4919
# Epoch 154/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7771 - loss: 0.4875
# Epoch 155/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - accuracy: 0.7815 - loss: 0.4801
# Epoch 156/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step - accuracy: 0.7941 - loss: 0.4689
# Epoch 157/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - accuracy: 0.7765 - loss: 0.4944
# Epoch 158/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step - accuracy: 0.7697 - loss: 0.4837
# Epoch 159/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - accuracy: 0.7735 - loss: 0.4876
# Epoch 160/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - accuracy: 0.7770 - loss: 0.4625
# Epoch 161/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7655 - loss: 0.5013
# Epoch 162/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - accuracy: 0.7716 - loss: 0.4810
# Epoch 163/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - accuracy: 0.7936 - loss: 0.4763
# Epoch 164/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - accuracy: 0.7702 - loss: 0.4945
# Epoch 165/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step - accuracy: 0.7785 - loss: 0.4843
# Epoch 166/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - accuracy: 0.7526 - loss: 0.4945
# Epoch 167/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step - accuracy: 0.7764 - loss: 0.4756
# Epoch 168/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step - accuracy: 0.7618 - loss: 0.4980
# Epoch 169/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step - accuracy: 0.7691 - loss: 0.4874
# Epoch 170/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - accuracy: 0.7800 - loss: 0.4726
# Epoch 171/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - accuracy: 0.7815 - loss: 0.4804
# Epoch 172/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step - accuracy: 0.7694 - loss: 0.4959
# Epoch 173/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step - accuracy: 0.7529 - loss: 0.5045
# Epoch 174/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step - accuracy: 0.7897 - loss: 0.4580
# Epoch 175/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step - accuracy: 0.7712 - loss: 0.4745
# Epoch 176/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7636 - loss: 0.4942
# Epoch 177/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step - accuracy: 0.7838 - loss: 0.4645
# Epoch 178/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - accuracy: 0.7781 - loss: 0.4717
# Epoch 179/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - accuracy: 0.7538 - loss: 0.4960
# Epoch 180/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - accuracy: 0.7818 - loss: 0.4690
# Epoch 181/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step - accuracy: 0.7469 - loss: 0.5095
# Epoch 182/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - accuracy: 0.7604 - loss: 0.4981
# Epoch 183/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - accuracy: 0.7804 - loss: 0.4682
# Epoch 184/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - accuracy: 0.7714 - loss: 0.4785
# Epoch 185/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - accuracy: 0.7762 - loss: 0.4763
# Epoch 186/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step - accuracy: 0.7998 - loss: 0.4598
# Epoch 187/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step - accuracy: 0.7932 - loss: 0.4525
# Epoch 188/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - accuracy: 0.7677 - loss: 0.4801
# Epoch 189/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step - accuracy: 0.7764 - loss: 0.4891
# Epoch 190/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - accuracy: 0.7643 - loss: 0.4890
# Epoch 191/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step - accuracy: 0.7649 - loss: 0.4870
# Epoch 192/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - accuracy: 0.7696 - loss: 0.4752
# Epoch 193/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step - accuracy: 0.7829 - loss: 0.4542
# Epoch 194/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - accuracy: 0.7549 - loss: 0.4925
# Epoch 195/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step - accuracy: 0.7570 - loss: 0.5004
# Epoch 196/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step - accuracy: 0.7571 - loss: 0.4954
# Epoch 197/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - accuracy: 0.7804 - loss: 0.4707
# Epoch 198/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step - accuracy: 0.7751 - loss: 0.4870
# Epoch 199/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - accuracy: 0.7956 - loss: 0.4607
# Epoch 200/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - accuracy: 0.8117 - loss: 0.4397
# Epoch 201/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - accuracy: 0.7907 - loss: 0.4651
# Epoch 202/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - accuracy: 0.7634 - loss: 0.4966
# Epoch 203/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step - accuracy: 0.7611 - loss: 0.4945
# Epoch 204/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.7798 - loss: 0.4559
# Epoch 205/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7639 - loss: 0.4873
# Epoch 206/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step - accuracy: 0.7688 - loss: 0.4836
# Epoch 207/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - accuracy: 0.7818 - loss: 0.4619
# Epoch 208/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - accuracy: 0.7569 - loss: 0.4892
# Epoch 209/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - accuracy: 0.7533 - loss: 0.5006
# Epoch 210/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - accuracy: 0.7754 - loss: 0.4798
# Epoch 211/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - accuracy: 0.7824 - loss: 0.4711
# Epoch 212/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - accuracy: 0.7922 - loss: 0.4536
# Epoch 213/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7594 - loss: 0.4925
# Epoch 214/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - accuracy: 0.7760 - loss: 0.4726
# Epoch 215/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step - accuracy: 0.7800 - loss: 0.4811
# Epoch 216/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - accuracy: 0.7738 - loss: 0.4687
# Epoch 217/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step - accuracy: 0.7545 - loss: 0.4954
# Epoch 218/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - accuracy: 0.7700 - loss: 0.4754
# Epoch 219/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - accuracy: 0.7722 - loss: 0.4709
# Epoch 220/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - accuracy: 0.7677 - loss: 0.4902
# Epoch 221/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - accuracy: 0.7834 - loss: 0.4674
# Epoch 222/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - accuracy: 0.7652 - loss: 0.4990
# Epoch 223/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - accuracy: 0.7793 - loss: 0.4698
# Epoch 224/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step - accuracy: 0.7731 - loss: 0.4858
# Epoch 225/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step - accuracy: 0.7813 - loss: 0.4566
# Epoch 226/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - accuracy: 0.7745 - loss: 0.4745
# Epoch 227/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7748 - loss: 0.4762
# Epoch 228/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - accuracy: 0.7516 - loss: 0.4968
# Epoch 229/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step - accuracy: 0.7728 - loss: 0.4788
# Epoch 230/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - accuracy: 0.7703 - loss: 0.4889
# Epoch 231/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - accuracy: 0.7842 - loss: 0.4569
# Epoch 232/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - accuracy: 0.7635 - loss: 0.4769
# Epoch 233/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - accuracy: 0.7811 - loss: 0.4700
# Epoch 234/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - accuracy: 0.7772 - loss: 0.4686
# Epoch 235/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7610 - loss: 0.4922
# Epoch 236/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step - accuracy: 0.7786 - loss: 0.4674
# Epoch 237/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - accuracy: 0.7700 - loss: 0.4726
# Epoch 238/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - accuracy: 0.7857 - loss: 0.4718
# Epoch 239/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step - accuracy: 0.7840 - loss: 0.4694
# Epoch 240/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - accuracy: 0.7872 - loss: 0.4520
# Epoch 241/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - accuracy: 0.7680 - loss: 0.4742
# Epoch 242/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - accuracy: 0.7525 - loss: 0.4971
# Epoch 243/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7801 - loss: 0.4699
# Epoch 244/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - accuracy: 0.7653 - loss: 0.4759
# Epoch 245/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - accuracy: 0.7794 - loss: 0.4675
# Epoch 246/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - accuracy: 0.7783 - loss: 0.4587
# Epoch 247/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step - accuracy: 0.7595 - loss: 0.4825
# Epoch 248/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - accuracy: 0.7633 - loss: 0.4649
# Epoch 249/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - accuracy: 0.7788 - loss: 0.4570
# Epoch 250/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step - accuracy: 0.7658 - loss: 0.4896
# Epoch 251/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step - accuracy: 0.7789 - loss: 0.4589
# Epoch 252/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - accuracy: 0.7752 - loss: 0.4642
# Epoch 253/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - accuracy: 0.7848 - loss: 0.4769
# Epoch 254/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step - accuracy: 0.7576 - loss: 0.4680
# Epoch 255/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - accuracy: 0.7869 - loss: 0.4611
# Epoch 256/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - accuracy: 0.7855 - loss: 0.4653
# Epoch 257/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - accuracy: 0.7678 - loss: 0.4724
# Epoch 258/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - accuracy: 0.7759 - loss: 0.4843
# Epoch 259/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - accuracy: 0.7785 - loss: 0.4656
# Epoch 260/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - accuracy: 0.7949 - loss: 0.4489
# Epoch 261/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - accuracy: 0.7640 - loss: 0.4758
# Epoch 262/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - accuracy: 0.7894 - loss: 0.4636
# Epoch 263/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step - accuracy: 0.7824 - loss: 0.4590
# Epoch 264/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7768 - loss: 0.4586
# Epoch 265/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - accuracy: 0.7800 - loss: 0.4694
# Epoch 266/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - accuracy: 0.7962 - loss: 0.4598
# Epoch 267/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - accuracy: 0.7773 - loss: 0.4637
# Epoch 268/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - accuracy: 0.7755 - loss: 0.4691
# Epoch 269/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - accuracy: 0.7877 - loss: 0.4451
# Epoch 270/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7878 - loss: 0.4506
# Epoch 271/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - accuracy: 0.7747 - loss: 0.4751
# Epoch 272/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - accuracy: 0.7769 - loss: 0.4542
# Epoch 273/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - accuracy: 0.7843 - loss: 0.4630
# Epoch 274/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - accuracy: 0.7627 - loss: 0.4956
# Epoch 275/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step - accuracy: 0.7804 - loss: 0.4936
# Epoch 276/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step - accuracy: 0.7817 - loss: 0.4737
# Epoch 277/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - accuracy: 0.7838 - loss: 0.4571
# Epoch 278/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7818 - loss: 0.4586
# Epoch 279/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - accuracy: 0.7924 - loss: 0.4612
# Epoch 280/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step - accuracy: 0.7798 - loss: 0.4540
# Epoch 281/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - accuracy: 0.7794 - loss: 0.4676
# Epoch 282/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - accuracy: 0.7906 - loss: 0.4559
# Epoch 283/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - accuracy: 0.7935 - loss: 0.4528
# Epoch 284/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - accuracy: 0.7793 - loss: 0.4822
# Epoch 285/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7696 - loss: 0.4814
# Epoch 286/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - accuracy: 0.7854 - loss: 0.4675
# Epoch 287/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - accuracy: 0.7815 - loss: 0.4738
# Epoch 288/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - accuracy: 0.7910 - loss: 0.4538
# Epoch 289/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - accuracy: 0.7880 - loss: 0.4666
# Epoch 290/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - accuracy: 0.8038 - loss: 0.4495
# Epoch 291/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - accuracy: 0.7801 - loss: 0.4622
# Epoch 292/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - accuracy: 0.7517 - loss: 0.5000
# Epoch 293/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - accuracy: 0.7995 - loss: 0.4554
# Epoch 294/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - accuracy: 0.7933 - loss: 0.4540
# Epoch 295/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - accuracy: 0.7803 - loss: 0.4704
# Epoch 296/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - accuracy: 0.7919 - loss: 0.4607
# Epoch 297/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - accuracy: 0.7896 - loss: 0.4620
# Epoch 298/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - accuracy: 0.7680 - loss: 0.4839
# Epoch 299/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step - accuracy: 0.7888 - loss: 0.4694
# Epoch 300/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - accuracy: 0.7996 - loss: 0.4393
# Epoch 301/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - accuracy: 0.8300 - loss: 0.4196
# Epoch 302/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step - accuracy: 0.7853 - loss: 0.4646
# Epoch 303/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step - accuracy: 0.7885 - loss: 0.4571
# Epoch 304/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step - accuracy: 0.7795 - loss: 0.4739
# Epoch 305/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - accuracy: 0.7908 - loss: 0.4620
# Epoch 306/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7862 - loss: 0.4538
# Epoch 307/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - accuracy: 0.7750 - loss: 0.4746
# Epoch 308/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - accuracy: 0.7829 - loss: 0.4679
# Epoch 309/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - accuracy: 0.7880 - loss: 0.4601
# Epoch 310/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - accuracy: 0.7992 - loss: 0.4452
# Epoch 311/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - accuracy: 0.7898 - loss: 0.4507
# Epoch 312/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - accuracy: 0.7825 - loss: 0.4673
# Epoch 313/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7779 - loss: 0.4634
# Epoch 314/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - accuracy: 0.7855 - loss: 0.4588
# Epoch 315/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - accuracy: 0.8013 - loss: 0.4497
# Epoch 316/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - accuracy: 0.8051 - loss: 0.4331
# Epoch 317/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - accuracy: 0.7926 - loss: 0.4596
# Epoch 318/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - accuracy: 0.7631 - loss: 0.4910
# Epoch 319/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - accuracy: 0.7800 - loss: 0.4615
# Epoch 320/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step - accuracy: 0.7966 - loss: 0.4602
# Epoch 321/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step - accuracy: 0.7883 - loss: 0.4672
# Epoch 322/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step - accuracy: 0.7810 - loss: 0.4799
# Epoch 323/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - accuracy: 0.7678 - loss: 0.4833
# Epoch 324/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step - accuracy: 0.7861 - loss: 0.4690
# Epoch 325/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - accuracy: 0.7962 - loss: 0.4505
# Epoch 326/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step - accuracy: 0.7964 - loss: 0.4519
# Epoch 327/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7916 - loss: 0.4567
# Epoch 328/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - accuracy: 0.7955 - loss: 0.4320
# Epoch 329/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - accuracy: 0.7768 - loss: 0.4670
# Epoch 330/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - accuracy: 0.7699 - loss: 0.4806
# Epoch 331/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step - accuracy: 0.7932 - loss: 0.4543
# Epoch 332/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - accuracy: 0.7575 - loss: 0.4951
# Epoch 333/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - accuracy: 0.7736 - loss: 0.4678
# Epoch 334/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - accuracy: 0.7899 - loss: 0.4586
# Epoch 335/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - accuracy: 0.7812 - loss: 0.4576
# Epoch 336/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step - accuracy: 0.8028 - loss: 0.4340
# Epoch 337/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step - accuracy: 0.7757 - loss: 0.4653
# Epoch 338/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - accuracy: 0.7908 - loss: 0.4437
# Epoch 339/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - accuracy: 0.7817 - loss: 0.4742
# Epoch 340/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - accuracy: 0.7832 - loss: 0.4517
# Epoch 341/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - accuracy: 0.8035 - loss: 0.4325
# Epoch 342/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step - accuracy: 0.7931 - loss: 0.4389
# Epoch 343/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - accuracy: 0.7932 - loss: 0.4452
# Epoch 344/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - accuracy: 0.7805 - loss: 0.4652
# Epoch 345/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - accuracy: 0.8039 - loss: 0.4373
# Epoch 346/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - accuracy: 0.7904 - loss: 0.4684
# Epoch 347/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - accuracy: 0.8138 - loss: 0.4186
# Epoch 348/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - accuracy: 0.7822 - loss: 0.4574
# Epoch 349/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - accuracy: 0.8017 - loss: 0.4423
# Epoch 350/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step - accuracy: 0.7904 - loss: 0.4609
# Epoch 351/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - accuracy: 0.7744 - loss: 0.4754
# Epoch 352/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - accuracy: 0.8095 - loss: 0.4320
# Epoch 353/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - accuracy: 0.8045 - loss: 0.4388
# Epoch 354/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7978 - loss: 0.4552
# Epoch 355/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step - accuracy: 0.7692 - loss: 0.4782
# Epoch 356/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - accuracy: 0.7783 - loss: 0.4630
# Epoch 357/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step - accuracy: 0.8043 - loss: 0.4437
# Epoch 358/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - accuracy: 0.7808 - loss: 0.4652
# Epoch 359/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - accuracy: 0.7940 - loss: 0.4517
# Epoch 360/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - accuracy: 0.7978 - loss: 0.4541
# Epoch 361/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8058 - loss: 0.4300
# Epoch 362/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step - accuracy: 0.7908 - loss: 0.4545
# Epoch 363/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step - accuracy: 0.7835 - loss: 0.4686
# Epoch 364/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - accuracy: 0.7885 - loss: 0.4639
# Epoch 365/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - accuracy: 0.8166 - loss: 0.4349
# Epoch 366/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - accuracy: 0.7784 - loss: 0.4554
# Epoch 367/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7886 - loss: 0.4492
# Epoch 368/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - accuracy: 0.7861 - loss: 0.4815
# Epoch 369/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - accuracy: 0.7771 - loss: 0.4762
# Epoch 370/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - accuracy: 0.7969 - loss: 0.4442
# Epoch 371/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - accuracy: 0.8103 - loss: 0.4426
# Epoch 372/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - accuracy: 0.7926 - loss: 0.4641
# Epoch 373/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - accuracy: 0.7857 - loss: 0.4742
# Epoch 374/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - accuracy: 0.7910 - loss: 0.4565
# Epoch 375/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - accuracy: 0.7941 - loss: 0.4567
# Epoch 376/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - accuracy: 0.7889 - loss: 0.4476
# Epoch 377/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - accuracy: 0.8125 - loss: 0.4366
# Epoch 378/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7859 - loss: 0.4683
# Epoch 379/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step - accuracy: 0.7869 - loss: 0.4599
# Epoch 380/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step - accuracy: 0.8021 - loss: 0.4510
# Epoch 381/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step - accuracy: 0.7569 - loss: 0.4908
# Epoch 382/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step - accuracy: 0.7989 - loss: 0.4546
# Epoch 383/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step - accuracy: 0.7772 - loss: 0.4828
# Epoch 384/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - accuracy: 0.7866 - loss: 0.4604
# Epoch 385/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7825 - loss: 0.4729
# Epoch 386/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - accuracy: 0.7816 - loss: 0.4564
# Epoch 387/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - accuracy: 0.7853 - loss: 0.4473
# Epoch 388/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step - accuracy: 0.8047 - loss: 0.4530
# Epoch 389/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - accuracy: 0.7810 - loss: 0.4647
# Epoch 390/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - accuracy: 0.7874 - loss: 0.4452
# Epoch 391/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7807 - loss: 0.4634
# Epoch 392/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - accuracy: 0.8159 - loss: 0.4466
# Epoch 393/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step - accuracy: 0.7954 - loss: 0.4488
# Epoch 394/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step - accuracy: 0.7831 - loss: 0.4558
# Epoch 395/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step - accuracy: 0.7951 - loss: 0.4542
# Epoch 396/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - accuracy: 0.7982 - loss: 0.4507
# Epoch 397/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - accuracy: 0.7953 - loss: 0.4463
# Epoch 398/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step - accuracy: 0.7926 - loss: 0.4578
# Epoch 399/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step - accuracy: 0.7879 - loss: 0.4562
# Epoch 400/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - accuracy: 0.7898 - loss: 0.4626
# Epoch 401/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - accuracy: 0.7975 - loss: 0.4588
# Epoch 402/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - accuracy: 0.7854 - loss: 0.4651
# Epoch 403/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - accuracy: 0.8002 - loss: 0.4522
# Epoch 404/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - accuracy: 0.7955 - loss: 0.4525
# Epoch 405/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - accuracy: 0.7946 - loss: 0.4621
# Epoch 406/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - accuracy: 0.8020 - loss: 0.4386
# Epoch 407/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step - accuracy: 0.8087 - loss: 0.4346
# Epoch 408/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - accuracy: 0.7717 - loss: 0.4739
# Epoch 409/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step - accuracy: 0.8166 - loss: 0.4401
# Epoch 410/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8022 - loss: 0.4429
# Epoch 411/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step - accuracy: 0.7944 - loss: 0.4507
# Epoch 412/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - accuracy: 0.7666 - loss: 0.4779
# Epoch 413/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - accuracy: 0.8092 - loss: 0.4205
# Epoch 414/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step - accuracy: 0.8145 - loss: 0.4347
# Epoch 415/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step - accuracy: 0.8239 - loss: 0.4286
# Epoch 416/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8131 - loss: 0.4303
# Epoch 417/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - accuracy: 0.7840 - loss: 0.4538
# Epoch 418/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - accuracy: 0.8085 - loss: 0.4394
# Epoch 419/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - accuracy: 0.7988 - loss: 0.4463
# Epoch 420/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - accuracy: 0.7835 - loss: 0.4743
# Epoch 421/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - accuracy: 0.8025 - loss: 0.4460
# Epoch 422/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8126 - loss: 0.4497
# Epoch 423/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - accuracy: 0.7835 - loss: 0.4816
# Epoch 424/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - accuracy: 0.8057 - loss: 0.4566
# Epoch 425/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step - accuracy: 0.8037 - loss: 0.4369
# Epoch 426/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - accuracy: 0.8262 - loss: 0.4262
# Epoch 427/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step - accuracy: 0.7907 - loss: 0.4650
# Epoch 428/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step - accuracy: 0.8075 - loss: 0.4367
# Epoch 429/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.8061 - loss: 0.4389
# Epoch 430/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step - accuracy: 0.8084 - loss: 0.4461
# Epoch 431/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step - accuracy: 0.7913 - loss: 0.4574
# Epoch 432/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step - accuracy: 0.8180 - loss: 0.4278
# Epoch 433/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7923 - loss: 0.4729
# Epoch 434/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - accuracy: 0.7701 - loss: 0.4881
# Epoch 435/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step - accuracy: 0.8051 - loss: 0.4543
# Epoch 436/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - accuracy: 0.8156 - loss: 0.4315
# Epoch 437/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step - accuracy: 0.8122 - loss: 0.4383
# Epoch 438/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step - accuracy: 0.7981 - loss: 0.4408
# Epoch 439/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step - accuracy: 0.8164 - loss: 0.4294
# Epoch 440/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step - accuracy: 0.7925 - loss: 0.4551
# Epoch 441/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - accuracy: 0.7980 - loss: 0.4580
# Epoch 442/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - accuracy: 0.7841 - loss: 0.4689
# Epoch 443/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - accuracy: 0.7887 - loss: 0.4595
# Epoch 444/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step - accuracy: 0.7968 - loss: 0.4633
# Epoch 445/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - accuracy: 0.7990 - loss: 0.4369
# Epoch 446/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step - accuracy: 0.8095 - loss: 0.4403
# Epoch 447/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - accuracy: 0.7884 - loss: 0.4747
# Epoch 448/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - accuracy: 0.8265 - loss: 0.4036
# Epoch 449/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step - accuracy: 0.7903 - loss: 0.4583
# Epoch 450/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7708 - loss: 0.4804
# Epoch 451/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - accuracy: 0.7824 - loss: 0.4809
# Epoch 452/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - accuracy: 0.7854 - loss: 0.4446
# Epoch 453/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step - accuracy: 0.7796 - loss: 0.4732
# Epoch 454/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - accuracy: 0.8032 - loss: 0.4601
# Epoch 455/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step - accuracy: 0.7988 - loss: 0.4522
# Epoch 456/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - accuracy: 0.7971 - loss: 0.4488
# Epoch 457/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7921 - loss: 0.4604
# Epoch 458/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step - accuracy: 0.7968 - loss: 0.4426
# Epoch 459/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - accuracy: 0.7919 - loss: 0.4594
# Epoch 460/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - accuracy: 0.7990 - loss: 0.4502
# Epoch 461/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step - accuracy: 0.8124 - loss: 0.4224
# Epoch 462/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7919 - loss: 0.4637
# Epoch 463/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - accuracy: 0.7918 - loss: 0.4607
# Epoch 464/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - accuracy: 0.8048 - loss: 0.4439
# Epoch 465/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8161 - loss: 0.4303
# Epoch 466/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - accuracy: 0.8029 - loss: 0.4538
# Epoch 467/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - accuracy: 0.7997 - loss: 0.4593
# Epoch 468/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - accuracy: 0.8200 - loss: 0.4294
# Epoch 469/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step - accuracy: 0.8081 - loss: 0.4323
# Epoch 470/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - accuracy: 0.8024 - loss: 0.4421
# Epoch 471/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - accuracy: 0.8021 - loss: 0.4499
# Epoch 472/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step - accuracy: 0.7981 - loss: 0.4506
# Epoch 473/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8297 - loss: 0.4110
# Epoch 474/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - accuracy: 0.7716 - loss: 0.4854
# Epoch 475/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - accuracy: 0.7868 - loss: 0.4698
# Epoch 476/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - accuracy: 0.7794 - loss: 0.4670
# Epoch 477/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - accuracy: 0.8027 - loss: 0.4549
# Epoch 478/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8201 - loss: 0.4377
# Epoch 479/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - accuracy: 0.7829 - loss: 0.4730
# Epoch 480/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step - accuracy: 0.8072 - loss: 0.4236
# Epoch 481/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 0.7786 - loss: 0.4678
# Epoch 482/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step - accuracy: 0.8033 - loss: 0.4501
# Epoch 483/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step - accuracy: 0.7805 - loss: 0.4824
# Epoch 484/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7745 - loss: 0.4713
# Epoch 485/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - accuracy: 0.8130 - loss: 0.4283
# Epoch 486/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - accuracy: 0.7891 - loss: 0.4613
# Epoch 487/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - accuracy: 0.7912 - loss: 0.4502
# Epoch 488/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - accuracy: 0.7954 - loss: 0.4597
# Epoch 489/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - accuracy: 0.7982 - loss: 0.4510
# Epoch 490/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - accuracy: 0.8064 - loss: 0.4423
# Epoch 491/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step - accuracy: 0.7991 - loss: 0.4530
# Epoch 492/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - accuracy: 0.8152 - loss: 0.4340
# Epoch 493/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step - accuracy: 0.8154 - loss: 0.4365
# Epoch 494/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step - accuracy: 0.7996 - loss: 0.4435
# Epoch 495/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - accuracy: 0.7991 - loss: 0.4539
# Epoch 496/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step - accuracy: 0.7882 - loss: 0.4682
# Epoch 497/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8102 - loss: 0.4457
# Epoch 498/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step - accuracy: 0.8102 - loss: 0.4333
# Epoch 499/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step - accuracy: 0.8156 - loss: 0.4249
# Epoch 500/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step - accuracy: 0.7963 - loss: 0.4593
# Epoch 501/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step - accuracy: 0.7960 - loss: 0.4524
# Epoch 502/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - accuracy: 0.8050 - loss: 0.4419
# Epoch 503/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step - accuracy: 0.8347 - loss: 0.4063
# Epoch 504/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step - accuracy: 0.8064 - loss: 0.4349
# Epoch 505/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - accuracy: 0.7849 - loss: 0.4603
# Epoch 506/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step - accuracy: 0.7852 - loss: 0.4643
# Epoch 507/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step - accuracy: 0.7942 - loss: 0.4558
# Epoch 508/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step - accuracy: 0.7904 - loss: 0.4475
# Epoch 509/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8194 - loss: 0.4238
# Epoch 510/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - accuracy: 0.8073 - loss: 0.4455
# Epoch 511/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - accuracy: 0.7940 - loss: 0.4500
# Epoch 512/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - accuracy: 0.8061 - loss: 0.4392
# Epoch 513/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - accuracy: 0.7851 - loss: 0.4637
# Epoch 514/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - accuracy: 0.8020 - loss: 0.4405
# Epoch 515/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8072 - loss: 0.4348
# Epoch 516/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - accuracy: 0.7919 - loss: 0.4407
# Epoch 517/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step - accuracy: 0.7878 - loss: 0.4568
# Epoch 518/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - accuracy: 0.7908 - loss: 0.4604
# Epoch 519/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step - accuracy: 0.7869 - loss: 0.4549
# Epoch 520/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7883 - loss: 0.4702
# Epoch 521/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step - accuracy: 0.8416 - loss: 0.4003
# Epoch 522/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step - accuracy: 0.7914 - loss: 0.4420
# Epoch 523/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - accuracy: 0.8070 - loss: 0.4482
# Epoch 524/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step - accuracy: 0.8115 - loss: 0.4322
# Epoch 525/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step - accuracy: 0.8010 - loss: 0.4396
# Epoch 526/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step - accuracy: 0.7663 - loss: 0.4790
# Epoch 527/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step - accuracy: 0.7907 - loss: 0.4569
# Epoch 528/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step - accuracy: 0.8186 - loss: 0.4324
# Epoch 529/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - accuracy: 0.8098 - loss: 0.4266
# Epoch 530/10000
# ...
# Epoch 9827/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - accuracy: 0.8339 - loss: 0.3805
# Epoch 9828/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - accuracy: 0.8385 - loss: 0.3656
# Epoch 9829/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - accuracy: 0.8440 - loss: 0.3619
# Epoch 9830/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step - accuracy: 0.8341 - loss: 0.3594
# Epoch 9831/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - accuracy: 0.8579 - loss: 0.3457
# Epoch 9832/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - accuracy: 0.8587 - loss: 0.3392
# Epoch 9833/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8366 - loss: 0.3831
# Epoch 9834/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step - accuracy: 0.8353 - loss: 0.3717
# Epoch 9835/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8515 - loss: 0.3668
# Epoch 9836/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step - accuracy: 0.8508 - loss: 0.3446
# Epoch 9837/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step - accuracy: 0.8159 - loss: 0.3971
# Epoch 9838/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - accuracy: 0.8243 - loss: 0.3831
# Epoch 9839/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - accuracy: 0.8336 - loss: 0.3804
# Epoch 9840/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - accuracy: 0.8370 - loss: 0.3610
# Epoch 9841/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - accuracy: 0.8487 - loss: 0.3442
# Epoch 9842/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step - accuracy: 0.8599 - loss: 0.3470
# Epoch 9843/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step - accuracy: 0.8451 - loss: 0.3580
# Epoch 9844/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step - accuracy: 0.8289 - loss: 0.3802
# Epoch 9845/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step - accuracy: 0.8524 - loss: 0.3423
# Epoch 9846/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - accuracy: 0.8315 - loss: 0.3717
# Epoch 9847/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 790us/step - accuracy: 0.8575 - loss: 0.3381
# Epoch 9848/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - accuracy: 0.8415 - loss: 0.3727
# Epoch 9849/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - accuracy: 0.8221 - loss: 0.4028
# Epoch 9850/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - accuracy: 0.8490 - loss: 0.3493
# Epoch 9851/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - accuracy: 0.8497 - loss: 0.3552
# Epoch 9852/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - accuracy: 0.8462 - loss: 0.3562
# Epoch 9853/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step - accuracy: 0.8430 - loss: 0.3596
# Epoch 9854/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - accuracy: 0.8263 - loss: 0.3704
# Epoch 9855/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step - accuracy: 0.8592 - loss: 0.3432
# Epoch 9856/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - accuracy: 0.8560 - loss: 0.3617
# Epoch 9857/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - accuracy: 0.8292 - loss: 0.4005
# Epoch 9858/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step - accuracy: 0.8586 - loss: 0.3458
# Epoch 9859/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - accuracy: 0.8509 - loss: 0.3621
# Epoch 9860/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step - accuracy: 0.8624 - loss: 0.3361
# Epoch 9861/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - accuracy: 0.8481 - loss: 0.3609
# Epoch 9862/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - accuracy: 0.8390 - loss: 0.3594
# Epoch 9863/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8427 - loss: 0.3735
# Epoch 9864/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step - accuracy: 0.8347 - loss: 0.3614
# Epoch 9865/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - accuracy: 0.8352 - loss: 0.3807
# Epoch 9866/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step - accuracy: 0.8344 - loss: 0.3826
# Epoch 9867/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step - accuracy: 0.8432 - loss: 0.3547
# Epoch 9868/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - accuracy: 0.8512 - loss: 0.3527
# Epoch 9869/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - accuracy: 0.8536 - loss: 0.3527
# Epoch 9870/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8346 - loss: 0.3777
# Epoch 9871/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - accuracy: 0.8245 - loss: 0.3952
# Epoch 9872/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step - accuracy: 0.8463 - loss: 0.3643
# Epoch 9873/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step - accuracy: 0.8373 - loss: 0.3524
# Epoch 9874/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step - accuracy: 0.8478 - loss: 0.3630
# Epoch 9875/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step - accuracy: 0.8441 - loss: 0.3514
# Epoch 9876/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - accuracy: 0.8397 - loss: 0.3726
# Epoch 9877/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step - accuracy: 0.8415 - loss: 0.3427
# Epoch 9878/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step - accuracy: 0.8348 - loss: 0.3809
# Epoch 9879/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8331 - loss: 0.3731
# Epoch 9880/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - accuracy: 0.8479 - loss: 0.3369
# Epoch 9881/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.8431 - loss: 0.3564
# Epoch 9882/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - accuracy: 0.8433 - loss: 0.3747
# Epoch 9883/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - accuracy: 0.8353 - loss: 0.3772
# Epoch 9884/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - accuracy: 0.8274 - loss: 0.3640
# Epoch 9885/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step - accuracy: 0.8414 - loss: 0.3738
# Epoch 9886/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step - accuracy: 0.8283 - loss: 0.3822
# Epoch 9887/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step - accuracy: 0.8446 - loss: 0.3643
# Epoch 9888/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8326 - loss: 0.3800
# Epoch 9889/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - accuracy: 0.8327 - loss: 0.3786
# Epoch 9890/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step - accuracy: 0.8549 - loss: 0.3444
# Epoch 9891/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - accuracy: 0.8349 - loss: 0.3894
# Epoch 9892/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step - accuracy: 0.8574 - loss: 0.3413
# Epoch 9893/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - accuracy: 0.8549 - loss: 0.3444
# Epoch 9894/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - accuracy: 0.8278 - loss: 0.3769
# Epoch 9895/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step - accuracy: 0.8285 - loss: 0.3820
# Epoch 9896/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8470 - loss: 0.3670
# Epoch 9897/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step - accuracy: 0.8443 - loss: 0.3593
# Epoch 9898/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - accuracy: 0.8379 - loss: 0.3841
# Epoch 9899/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step - accuracy: 0.8506 - loss: 0.3653
# Epoch 9900/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - accuracy: 0.8464 - loss: 0.3520
# Epoch 9901/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step - accuracy: 0.8329 - loss: 0.3693
# Epoch 9902/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step - accuracy: 0.8617 - loss: 0.3596
# Epoch 9903/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8337 - loss: 0.3920
# Epoch 9904/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8521 - loss: 0.3525
# Epoch 9905/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step - accuracy: 0.8567 - loss: 0.3475
# Epoch 9906/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.8580 - loss: 0.3371
# Epoch 9907/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step - accuracy: 0.8519 - loss: 0.3525
# Epoch 9908/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - accuracy: 0.8369 - loss: 0.3795
# Epoch 9909/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step - accuracy: 0.8313 - loss: 0.3648
# Epoch 9910/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8486 - loss: 0.3525
# Epoch 9911/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step - accuracy: 0.8471 - loss: 0.3519
# Epoch 9912/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - accuracy: 0.8343 - loss: 0.3959
# Epoch 9913/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - accuracy: 0.8519 - loss: 0.3590
# Epoch 9914/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 540us/step - accuracy: 0.8517 - loss: 0.3658
# Epoch 9915/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step - accuracy: 0.8396 - loss: 0.3699
# Epoch 9916/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - accuracy: 0.8462 - loss: 0.3428
# Epoch 9917/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - accuracy: 0.8548 - loss: 0.3520
# Epoch 9918/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step - accuracy: 0.8421 - loss: 0.3774
# Epoch 9919/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8657 - loss: 0.3517
# Epoch 9920/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - accuracy: 0.8498 - loss: 0.3636
# Epoch 9921/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - accuracy: 0.8360 - loss: 0.3797
# Epoch 9922/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step - accuracy: 0.8456 - loss: 0.3269
# Epoch 9923/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step - accuracy: 0.8212 - loss: 0.3901
# Epoch 9924/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step - accuracy: 0.8343 - loss: 0.3900
# Epoch 9925/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - accuracy: 0.8547 - loss: 0.3549
# Epoch 9926/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8536 - loss: 0.3592
# Epoch 9927/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - accuracy: 0.8364 - loss: 0.3705
# Epoch 9928/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - accuracy: 0.8489 - loss: 0.3550
# Epoch 9929/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - accuracy: 0.8570 - loss: 0.3530
# Epoch 9930/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 786us/step - accuracy: 0.8202 - loss: 0.3952
# Epoch 9931/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step - accuracy: 0.8383 - loss: 0.3791
# Epoch 9932/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step - accuracy: 0.8581 - loss: 0.3402
# Epoch 9933/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.8381 - loss: 0.3740
# Epoch 9934/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8345 - loss: 0.3677
# Epoch 9935/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step - accuracy: 0.8324 - loss: 0.3904
# Epoch 9936/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - accuracy: 0.8372 - loss: 0.3734
# Epoch 9937/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - accuracy: 0.8154 - loss: 0.4002
# Epoch 9938/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step - accuracy: 0.8408 - loss: 0.3829
# Epoch 9939/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - accuracy: 0.8411 - loss: 0.3704
# Epoch 9940/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8312 - loss: 0.3763
# Epoch 9941/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8507 - loss: 0.3395
# Epoch 9942/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8313 - loss: 0.3709
# Epoch 9943/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step - accuracy: 0.8591 - loss: 0.3354
# Epoch 9944/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - accuracy: 0.8297 - loss: 0.3883
# Epoch 9945/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - accuracy: 0.8455 - loss: 0.3636
# Epoch 9946/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step - accuracy: 0.8445 - loss: 0.3686
# Epoch 9947/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - accuracy: 0.8409 - loss: 0.3472
# Epoch 9948/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 0.8424 - loss: 0.3570
# Epoch 9949/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8406 - loss: 0.3709
# Epoch 9950/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8440 - loss: 0.3487
# Epoch 9951/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step - accuracy: 0.8487 - loss: 0.3593
# Epoch 9952/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step - accuracy: 0.8209 - loss: 0.3946
# Epoch 9953/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step - accuracy: 0.8246 - loss: 0.3960
# Epoch 9954/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - accuracy: 0.8382 - loss: 0.3695
# Epoch 9955/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step - accuracy: 0.8629 - loss: 0.3396
# Epoch 9956/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - accuracy: 0.8593 - loss: 0.3512
# Epoch 9957/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 0.8357 - loss: 0.3759
# Epoch 9958/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 0.8281 - loss: 0.3765
# Epoch 9959/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - accuracy: 0.8312 - loss: 0.3772
# Epoch 9960/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - accuracy: 0.8377 - loss: 0.3643
# Epoch 9961/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step - accuracy: 0.8405 - loss: 0.3865
# Epoch 9962/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step - accuracy: 0.8346 - loss: 0.3648
# Epoch 9963/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step - accuracy: 0.8302 - loss: 0.3811
# Epoch 9964/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step - accuracy: 0.8501 - loss: 0.3588
# Epoch 9965/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8315 - loss: 0.3743
# Epoch 9966/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8450 - loss: 0.3475
# Epoch 9967/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step - accuracy: 0.8445 - loss: 0.3646
# Epoch 9968/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - accuracy: 0.8384 - loss: 0.3911
# Epoch 9969/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step - accuracy: 0.8368 - loss: 0.3732
# Epoch 9970/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - accuracy: 0.8526 - loss: 0.3355
# Epoch 9971/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - accuracy: 0.8242 - loss: 0.3958
# Epoch 9972/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - accuracy: 0.8634 - loss: 0.3235
# Epoch 9973/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8566 - loss: 0.3643
# Epoch 9974/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step - accuracy: 0.8215 - loss: 0.3987
# Epoch 9975/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - accuracy: 0.8420 - loss: 0.3579
# Epoch 9976/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.8152 - loss: 0.4007
# Epoch 9977/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8587 - loss: 0.3532
# Epoch 9978/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step - accuracy: 0.8531 - loss: 0.3634
# Epoch 9979/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 0.8398 - loss: 0.3743
# Epoch 9980/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - accuracy: 0.8512 - loss: 0.3659
# Epoch 9981/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8364 - loss: 0.3957
# Epoch 9982/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - accuracy: 0.8280 - loss: 0.3804
# Epoch 9983/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step - accuracy: 0.8398 - loss: 0.3680
# Epoch 9984/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - accuracy: 0.8418 - loss: 0.3770
# Epoch 9985/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - accuracy: 0.8298 - loss: 0.3922
# Epoch 9986/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - accuracy: 0.8415 - loss: 0.3838
# Epoch 9987/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - accuracy: 0.8473 - loss: 0.3631
# Epoch 9988/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step - accuracy: 0.8286 - loss: 0.3820
# Epoch 9989/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8525 - loss: 0.3443
# Epoch 9990/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - accuracy: 0.8576 - loss: 0.3269
# Epoch 9991/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step - accuracy: 0.8462 - loss: 0.3654
# Epoch 9992/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step - accuracy: 0.8415 - loss: 0.3760
# Epoch 9993/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - accuracy: 0.8495 - loss: 0.3689
# Epoch 9994/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - accuracy: 0.8288 - loss: 0.3814
# Epoch 9995/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step - accuracy: 0.8454 - loss: 0.3582
# Epoch 9996/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - accuracy: 0.8354 - loss: 0.3661
# Epoch 9997/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - accuracy: 0.8419 - loss: 0.3687
# Epoch 9998/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - accuracy: 0.8470 - loss: 0.3643
# Epoch 9999/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 786us/step - accuracy: 0.8400 - loss: 0.3744
# Epoch 10000/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step - accuracy: 0.8338 - loss: 0.3767

# %% [markdown]
# ### Step 2: Preparing the testing data
#
# Steps for preprocessing the testing data:
# <ol>
# <li>Importing data and exploring the features.</li>
# <li>Cleaning data: Handling missing values</li>
# <li>Creating new features and dropping redundant features.</li>
# <li>Transforming data.</li>
# </ol>

# %% [markdown]
# #### Step 2.1 Importing data and exploring the features
# ##### Step 2.1.1
# Read the csv file 'titanic-test.csv' using Pandas' read_csv function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html">pandas.read_csv</a>)
# Note: Run a code cell by clicking on the cell and using the keyboard shortcut &lt;Shift&gt; + &lt;Enter&gt;.

# %%
test_data = pd.read_csv('titanic-test.csv')

# %% [markdown]
# ##### Step 2.1.2
# Use head function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.head.html">pandas.DataFrame.head</a>) of pandas library to preview the first 10 data.

# %%
print(test_data.head(10))
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0  34.5      0      0     330911   7.8292   NaN        Q
# 1  47.0      1      0     363272   7.0000   NaN        S
# 2  62.0      0      0     240276   9.6875   NaN        Q
# 3  27.0      0      0     315154   8.6625   NaN        S
# 4  22.0      1      1    3101298  12.2875   NaN        S
# 5  14.0      0      0       7538   9.2250   NaN        S
# 6  30.0      0      0     330972   7.6292   NaN        Q
# 7  26.0      1      1     248738  29.0000   NaN        S
# 8  18.0      0      0       2657   7.2292   NaN        C
# 9  21.0      2      0  A/4 48871  24.1500   NaN        S

# %% [markdown]
# ##### Step 2.1.3
# Use tail function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.tail.html">pandas.DataFrame.tail</a>) of pandas library to preview the last 10 data.

# %%
print(test_data.tail(10))
# Out:
#      PassengerId  Pclass                                             Name  \
# 408         1300       3                  Riordan, Miss. Johanna Hannah""
# 409         1301       3                        Peacock, Miss. Treasteall
# 410         1302       3                           Naughton, Miss. Hannah
# 411         1303       1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 412         1304       3                   Henriksson, Miss. Jenny Lovisa
# 413         1305       3                               Spector, Mr. Woolf
# 414         1306       1                     Oliva y Ocana, Dona. Fermina
# 415         1307       3                     Saether, Mr. Simon Sivertsen
# 416         1308       3                              Ware, Mr. Frederick
# 417         1309       3                         Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 408  female   NaN      0      0              334915    7.7208   NaN        Q
# 409  female   3.0      1      1  SOTON/O.Q. 3101315   13.7750   NaN        S
# 410  female   NaN      0      0              365237    7.7500   NaN        Q
# 411  female  37.0      1      0               19928   90.0000   C78        Q
# 412  female  28.0      0      0              347086    7.7750   NaN        S
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C

# %% [markdown]
# ##### Step 2.1.4
# Display informtion on dataframe using info function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.info.html">pandas.DataFrame.info</a>) of pandas library.

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %% [markdown]
# ##### Step 2.1.5
# Evaluate the data quality & perform missing values assessment using isnull function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.isnull.html">pandas.isnull</a>) and sum function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sum.html">pandas.DataFrame.sum</a>) of pandas library.

# %%
missing_values = test_data.isnull().sum()
print(missing_values[missing_values > 0])
# Out:
# Age       86
# Fare       1
# Cabin    327
# dtype: int64

# %% [markdown]
# ##### Step 2.1.6
# Evaluate the distribution of categorical features (e.g., Name, Sex, Ticket, Cabin, and Embarked) using describe function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.describe.html">pandas.DataFrame.describe</a>) of the pandas library.

# %%
categorical_description = test_data.describe(include='object')

print(categorical_description)
# Out:
#                     Name   Sex    Ticket            Cabin Embarked
# count                418   418       418               91      418
# unique               418     2       363               76        3
# top     Kelly, Mr. James  male  PC 17608  B57 B59 B63 B66        S
# freq                   1   266         5                3      270

# %% [markdown]
# #### Step 2.2 Cleaning Data: Handling missing values
# ##### Step 2.2.1
# Refer to Step 2.1.5, there are missing values in three features.
# For the feature with the second least number of missing values, evaluate its distribution using hist function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.hist.html">pandas.DataFrame.hist</a>) of pandas library.

# %%
plt.figure(figsize=(10, 6))
test_data['Age'].hist(bins=20, edgecolor='black')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# #### Step 2.2.2
# - For the feature with the second least missing values, if the data is not skewed, using mean to impute the missing values. Otherwise using median.
#
# ##### Step 2.2.2.1
# Compute the mean OR median of the second least missing values using mean (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.mean.html">pandas.DataFrame.mean</a>) / median function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.median.html">pandas.DataFrame.median</a>) of pandas library.
#
# Note: You have to skip all the missing values when computing the mean or median.

# %%
median_age = test_data['Age'].median()
print(f'Median value for Age: {median_age}')
# Out:
# Median value for Age: 27.0

# %% [markdown]
# ##### Step 2.2.2.2
# Use the mean value of the feature with the least missing values to impute the missing values. Again, fillna function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.fillna.html">pandas.DataFrame.fillna</a>) of the pandas library can be used.

# %%
mean_fare = test_data['Fare'].mean()
print(f'Mean value for Fare: {mean_fare}')

# Impute missing values in the Fare column with the mean
test_data['Fare'].fillna(mean_fare, inplace=True)
# Out:
# Mean value for Fare: 35.627188489208635
# /var/folders/sg/4n9pw8hs0719q3wb9rbg6_z00000gn/T/ipykernel_6688/4140282905.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_data['Fare'].fillna(mean_fare, inplace=True)

# %% [markdown]
# ##### Step 2.2.2.3
# Use mean / median to impute the missing values of the feature with the second least missing values. fillna function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.fillna.html">pandas.DataFrame.fillna</a>) of pandas library can be used.

# %%
median_age = test_data['Age'].median()
print(f'Median value for Age: {median_age}')

test_data['Age'].fillna(median_age, inplace=True)
# Out:
# Median value for Age: 27.0
# /var/folders/sg/4n9pw8hs0719q3wb9rbg6_z00000gn/T/ipykernel_6688/1535218582.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_data['Age'].fillna(median_age, inplace=True)

# %% [markdown]
# #### Step 2.3: Creating new features and dropping redundant features
# ##### Step 2.3.1
# Create a new feature called Family based on Parch and SibSp.
# - Define a new feature 'Family' and assign it with the sum of SibSp and Parch.

# %%
test_data['Family'] = test_data['Parch'] + test_data['SibSp']

# %% [markdown]
# ##### Step 2.3.2
# Use head function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.head.html">pandas.DataFrame.head</a>) of pandas library to preview the first 10 data.

# %%
print(test_data[['Parch', 'SibSp', 'Family']].head(10))
# Out:
#    Parch  SibSp  Family
# 0      0      0       0
# 1      0      1       1
# 2      0      0       0
# 3      0      0       0
# 4      1      1       2
# 5      0      0       0
# 6      0      0       0
# 7      1      1       2
# 8      0      0       0
# 9      0      2       2

# %% [markdown]
# ##### Step 2.3.3
# - PassengerId, Name, Ticket, and Cabin may be dropped (using drop function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.drop.html">pandas.DataFrame.drop</a>) of the pandas library) as they contain high ratio of duplicates and there may not be a correlation to survivial.
# - In addition, SibSp and Parch can be dropped as the feature 'Family' has been defined.

# %%
columns_to_drop = ['PassengerId', 'Name', 'Ticket', 'Cabin', 'SibSp', 'Parch']
test_data.drop(columns=columns_to_drop, inplace=True)

# %% [markdown]
# ##### Step 2.3.4
# Use head function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.head.html">pandas.DataFrame.head</a>) of pandas library to preview the first 10 data.

# %%
print(test_data.head(10))
# Out:
#    Pclass     Sex   Age     Fare Embarked  Family
# 0       3    male  34.5   7.8292        Q       0
# 1       3  female  47.0   7.0000        S       1
# 2       2    male  62.0   9.6875        Q       0
# 3       3    male  27.0   8.6625        S       0
# 4       3  female  22.0  12.2875        S       2
# 5       3    male  14.0   9.2250        S       0
# 6       3  female  30.0   7.6292        Q       0
# 7       2    male  26.0  29.0000        S       2
# 8       3  female  18.0   7.2292        C       0
# 9       3    male  21.0  24.1500        S       2

# %% [markdown]
# #### Step 2.4: Transforming data
# ##### Step 2.4.1
# - Update the Family's values using where function (<a href="https://docs.scipy.org/doc/numpy-1.14.0/reference/generated/numpy.where.html">numpy.where</a>) of numpy library as follows:
# <ul>
#     <li>0 if the Family's count is 0, which means single.</li>
#     <li>1 if the Family's count is greater than or equal to 1 AND less than or equal to 4, which means small family.</li>
#     <li>2 if the Family's count is greater than or equal to 5, means large family</li>
# </ul>

# %%
test_data['Family'] = np.where(test_data['Family'] == 0, 0,
                                np.where((test_data['Family'] >= 1) & (test_data['Family'] <= 4), 1, 2))

print(test_data[['Family']].head())
# Out:
#    Family
# 0       0
# 1       1
# 2       0
# 3       0
# 4       1

# %% [markdown]
# ##### Step 2.4.2
# - Update the Sex's values to 1 if the original value is 'male'. Otherwise, update it to 0.
# - where function (<a href="https://docs.scipy.org/doc/numpy-1.14.0/reference/generated/numpy.where.html">numpy.where</a>) of numpy library can be used.

# %%
test_data['Sex'] = np.where(test_data['Sex'] == 'male', 1, 0)

print(test_data[['Sex']].head())
# Out:
#    Sex
# 0    1
# 1    0
# 2    1
# 3    1
# 4    0

# %% [markdown]
# ##### Step 2.4.3
# - Update the Embarked values using where function (<a href="https://docs.scipy.org/doc/numpy-1.14.0/reference/generated/numpy.where.html">numpy.where</a>) of numpy library as follows:
# <ul>
#     <li>0 if the Embarked value is C.</li>
#     <li>1 if the Embarked value is Q.</li>
#     <li>2 if teh Embarked value is S.</li>
# </ul>

# %%
test_data['Embarked'] = np.where(test_data['Embarked'] == 'C', 0,
                                  np.where(test_data['Embarked'] == 'Q', 1,
                                           np.where(test_data['Embarked'] == 'S', 2, np.nan)))

print(test_data[['Embarked']].head())
# Out:
#    Embarked
# 0       1.0
# 1       2.0
# 2       1.0
# 3       2.0
# 4       2.0

# %% [markdown]
# ##### Step 2.4.4
# - Update the Fare values using where function (<a href="https://docs.scipy.org/doc/numpy-1.14.0/reference/generated/numpy.where.html">numpy.where</a>) of numpy library as follows:
# <ul>
#     <li>0 if the Fare value is less than or equal to 7.91</li>
#     <li>1 if the Fare value is greater than 7.91 AND less than or equal to 14.454</li>
#     <li>2 if the Fare value is greater than 14.454 AND less than or equal to 31</li>
#     <li>3 if the Fare value is greater than 31</li>
# </ul>

# %%
test_data['Fare'] = np.where(test_data['Fare'] <= 7.91, 0,
                              np.where((test_data['Fare'] > 7.91) & (test_data['Fare'] <= 14.454), 1,
                                       np.where((test_data['Fare'] > 14.454) & (test_data['Fare'] <= 31), 2, 3)))


print(test_data[['Fare']].head())
# Out:
#    Fare
# 0     0
# 1     0
# 2     1
# 3     1
# 4     1

# %% [markdown]
# ##### Step 2.4.5
# - Update the Age values using where function (<a href="https://docs.scipy.org/doc/numpy-1.14.0/reference/generated/numpy.where.html">numpy.where</a>) of numpy library as follows:
# <ul>
#     <li>0 if the Age value is less than or equal to 16</li>
#     <li>1 if the Age value is greater than 16 AND less than or equal to 32</li>
#     <li>2 if the Age value is greater than 32 AND less than or equal to 48</li>
#     <li>3 if the Age value is greater than 48 AND less than or equal to 64</li>
#     <li>4 if the Age value is greater than 64</li>
# </ul>

# %%
test_data['Age'] = np.where(test_data['Age'] <= 16, 0,
                             np.where((test_data['Age'] > 16) & (test_data['Age'] <= 32), 1,
                                      np.where((test_data['Age'] > 32) & (test_data['Age'] <= 48), 2,
                                               np.where((test_data['Age'] > 48) & (test_data['Age'] <= 64), 3, 4))))


print(test_data[['Age']].head())
# Out:
#    Age
# 0    2
# 1    2
# 2    3
# 3    1
# 4    1

# %% [markdown]
# ##### Step 2.4.6
# Change Embarked data to int type using astype function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.astype.html">pandas.DataFrame.astype</a>) of pandas library.

# %%
test_data['Embarked'] = test_data['Embarked'].astype(int)

print(test_data[['Embarked']].head())
# Out:
#    Embarked
# 0         1
# 1         2
# 2         1
# 3         2
# 4         2

# %% [markdown]
# ##### Step 2.4.7
# Change Fare data from float to int type using astype function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.astype.html">pandas.DataFrame.astype</a>) of pandas library.

# %%
test_data['Fare'] = test_data['Fare'].astype(int)


print(test_data[['Fare']].head())
# Out:
#    Fare
# 0     0
# 1     0
# 2     1
# 3     1
# 4     1

# %% [markdown]
# ##### Step 2.4.8
# Change Age data from float to int type using astype function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.astype.html">pandas.DataFrame.astype</a>) of pandas library.

# %%
test_data['Age'] = test_data['Age'].astype(int)

print(test_data[['Age']].head())
# Out:
#    Age
# 0    2
# 1    2
# 2    3
# 3    1
# 4    1

# %% [markdown]
# ##### Step 2.4.9
# Use head function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.head.html">pandas.DataFrame.head</a>) of pandas library to preview the first 20 data.

# %%
print(test_data.head(20))
# Out:
#     Pclass  Sex  Age  Fare  Embarked  Family
# 0        3    1    2     0         1       0
# 1        3    0    2     0         2       1
# 2        2    1    3     1         1       0
# 3        3    1    1     1         2       0
# 4        3    0    1     1         2       1
# 5        3    1    0     1         2       0
# 6        3    0    1     0         1       0
# 7        2    1    1     2         2       1
# 8        3    0    1     0         0       0
# 9        3    1    1     2         2       1
# 10       3    1    1     0         2       0
# 11       1    1    2     2         2       0
# 12       1    0    1     3         2       1
# 13       2    1    3     2         2       1
# 14       1    0    2     3         2       1
# 15       2    0    1     2         0       1
# 16       2    1    2     1         1       0
# 17       3    1    1     0         0       0
# 18       3    0    1     1         2       1
# 19       3    0    2     0         0       0

# %% [markdown]
# ### Step 3: Use the NN model to predict the results
#
# Predicting whether or not the passengers survived the sinking of the Titanic.
# <ol>
#     <li>Use predict function of NN to predict testData. The predictions will be in the range between 0 and 1.</li>
#     <li>If the predicted value is greater than 0.5, set it to 1, otherwise, set it to 0.
#     </li>
#     <li>Save the classification results to a CSV file: prediction-ann.csv (for example, you may use the pandas.DataFrame.to_csv function).</li>
# </ol>

# %%
features = test_data[['Pclass', 'Sex', 'Age', 'Fare', 'Embarked', 'Family']]

predictions = NN.predict(features)

binary_predictions = (predictions > 0.5).astype(int)

results = pd.DataFrame({
    'Survived': binary_predictions.flatten() 
})

results.to_csv('prediction-ann.csv', index=False)

print(results.head(20))
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#     Survived
# 0          0
# 1          1
# 2          0
# 3          0
# 4          0
# 5          0
# 6          1
# 7          0
# 8          1
# 9          0
# 10         0
# 11         0
# 12         1
# 13         0
# 14         1
# 15         1
# 16         0
# 17         0
# 18         0
# 19         1

# %% [markdown]
# ### Submission
# Submit your jupyter notebook (.ipynb) and the classification results (prediction-ann.csv).
